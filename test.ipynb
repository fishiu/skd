# %%
import pandas as pd
import utils.config as config

full_data = pd.read_csv(config.path_movie_omdb)
full_data.head()
# Out:
#    Idx           Title  Year  Rated     Released  Runtime  \
# 0    1       Inception  2010  PG-13  16 Jul 2010  148 min
# 1    2  Shutter Island  2010      R  19 Feb 2010  138 min
# 2    3     Toy Story 3  2010      G  18 Jun 2010  103 min
# 3    4      Iron Man 2  2010  PG-13  07 May 2010  124 min
# 4    5      Black Swan  2010      R  17 Dec 2010  108 min
#
#                                            Genre           Director  \
# 0            Action, Adventure, Sci-Fi, Thriller  Christopher Nolan
# 1                              Mystery, Thriller    Martin Scorsese
# 2  Animation, Adventure, Comedy, Family, Fantasy        Lee Unkrich
# 3                      Action, Adventure, Sci-Fi        Jon Favreau
# 4                                Drama, Thriller   Darren Aronofsky
#
#                                               Writer  \
# 0                                  Christopher Nolan
# 1  Laeta Kalogridis (screenplay), Dennis Lehane (...
# ...

# %%
import seaborn as sns
sns.heatmap(full_data.isnull(), cbar=False, cmap='PuBu')
# Out:
# <AxesSubplot:>
